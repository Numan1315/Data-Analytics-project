# %%
import pandas as pd
import numpy as np
import datetime as dt
from math import cos, asin, sqrt, pi
import ast
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ### Function to get the time of the user order

# %%
def choosetime(t,user):
    if(t<dt.time(11,30) and t>=dt.time(5,30)):
        mor=user[(user['Time'].dt.time < dt.time(11,30)) & (user['Time'].dt.time >= dt.time(5,30))]
        return mor
    elif(t>=dt.time(11,30) and t<dt.time(16,0)):
        noon=user[(user['Time'].dt.time >= dt.time(11,30)) & (user['Time'].dt.time < dt.time(16,0))]
        return noon
    else:
        night=user[(user['Time'].dt.time >= dt.time(16,0)) | (user['Time'].dt.time < dt.time(5,30))]
        return night

# %%
def timing_user(user,t):
    timing=choosetime(t,user)
    c=0
    while(len(timing)==0 and c<2):
        c+=1
        if(dt.time(5,30)<=t and t<dt.time(11,30)):
            t=dt.time(12,0)
            timing=choosetime(t,user)
        elif(dt.time(16,0)>t and t>=dt.time(11,30)):
            t=dt.time(17,0)
            timing=choosetime(t,user)
        else:
            t=dt.time(12,0)
            timing=choosetime(t,user)
    return timing

# %% [markdown]
# ### Function to get list of all dishes and cuisines from the dataset

# %%
def df_dish_cui(df):
    df_cui = []
    for i in df.cuisines:
        df_cui.append(list(set(i)))
    df_dish = []
    for i in df.dish_liked:
        df_dish.append(list(set(i)))
    return df_cui,df_dish

# %% [markdown]
# ### Function to clean the user data based on dish_liked column and cuisines column

# %%
def clean_user_p1(user):
    user_dish = []
    user_dish1=[]
    for i in timing.Food_ordered:
        res =ast.literal_eval(i)
        for j in res:
            user_dish.append(j)
    for i in user_dish:
        w = i.lower()
        z = w.replace('ml','').replace('grams','').replace('  ','').replace('kg','').replace('XXL','').replace('pack of','').replace('pack','').replace('packs','').replace('-','').replace('capacity','').replace('"','').replace(' of','').replace('{','').replace('}','').replace('.','').replace('  ','').replace('mini','').replace('special','').replace('pieces','').replace('piece','').replace('with','').replace('combo','').replace('extra','').replace('classic','').replace('sub','').replace('inches','').replace('delight','').replace('and','').replace('small','').replace('medium','').replace('large','').replace('sundae','').replace('sunday','').replace('in','').replace('slices','')        
        fin = re.sub(r"\([^()]*\)",'',z)
        user_dish1.append(fin)
    return user_dish1

# %%
def clean_user_p2(dish_liked):
    pan = ['panner','panneer']
    idl = ['idly','idlis']
    momo = ['momo']
    roti = ['rotis','rotti']
    vada = ['wada']
    chilli = ['chilli','chilii','chily']
    pp = ['pani puri','paani puri','panipuri']
    sp = ['sev puri','sevpuri']
    dp = ['dahi puri','dahipuri']
    choco = ['chococlate','choco','chcocolate','']
    pap = [' papadi']
    parata = ['paratha', 'parantha', 'parate', 'parathe' ,'parotta', 'parota', 'parotha']
    icecream = ['ice cream']
    donut = ['doughnut']
    cheesecake=['cheese cake']
    pancake = ['pan cake']
    raita=['raitha']
    rabdi=['rabri']
    halwa=['halva']
    kebab = ['kabab','kebeb']
    chapati = ['chapathi','chapatti']
    dabeli = ['dhabeli']
    sabji = ['subji','subzi','sabzi','sabji','gravy']
    jamoon = ['jamoon']
    barfi = ['barfi']
    chawal = ['chawal']
    for j,z in zip(dish_liked,range(len(dish_liked))):
        if re.search('pan' , j):
            dish_liked[z] = ' '.join("paneer" if i in pan else i for i in j.split())
        if re.search('idl' , j):
            dish_liked[z] = ' '.join("idli" if i in idl else i for i in j.split())
        if re.search('momo' , j):
            dish_liked[z] = ' '.join("momos" if i in momo else i for i in j.split())
        if re.search('roti' , j):
            dish_liked[z] = ' '.join("roti" if i in roti else i for i in j.split())
        if re.search('vada' , j):
            dish_liked[z] = ' '.join("vada"if i in vada else i for i in j.split())
        if re.search('pani' , j):
            dish_liked[z] = ' '.join("chaat" if i in pp else i for i in j.split())
        if re.search('sev' , j):
            dish_liked[z] = ' '.join("chaat" if i in sp else i for i in j.split())
        if re.search('dahi' , j):
            dish_liked[z] = ' '.join("chaat" if i in dp else i for i in j.split())
        if re.search('chil' , j):
            dish_liked[z] = ' '.join("chilli" if i in chilli else i for i in j.split())
        if re.search('ch' , j):
            dish_liked[z] = ' '.join("chocolate" if i in choco else i for i in j.split())
        if re.search('pap' , j):
            dish_liked[z] = ' '.join("papdi" if i in pap else i for i in j.split())
        if re.search('par' , j):
            dish_liked[z] = ' '.join("parata" if i in parata else i for i in j.split())
        if re.search('ice ' , j):
            dish_liked[z] = ' '.join("icecream" if i in icecream else i for i in j.split())
        if re.search('doug' , j):
            dish_liked[z] = ' '.join("donut" if i in donut else i for i in j.split())
        if re.search('cheese' , j):
            dish_liked[z] = ' '.join("cheesecake" if i in cheesecake else i for i in j.split())
        if re.search('pan' , j):
            dish_liked[z] = ' '.join("pancake" if i in pancake else i for i in j.split())
        if re.search('rait' , j):
            dish_liked[z] = ' '.join("raita" if i in raita else i for i in j.split())
        if re.search('rab' , j):
            dish_liked[z] = ' '.join("rabdi" if i in rabdi else i for i in j.split())
        if re.search('hal' , j):
            dish_liked[z] = ' '.join("halwa" if i in halwa else i for i in j.split())
        if re.search('k' , j):
            dish_liked[z] = ' '.join("kebab" if i in kebab else i for i in j.split())
        if re.search('chapa' , j):
            dish_liked[z] = ' '.join("chapati" if i in chapati else i for i in j.split())
        if re.search('dhab' , j):
            dish_liked[z] = ' '.join("dabeli" if i in dabeli else i for i in j.split())
        if re.search('s' , j):
            dish_liked[z] = ' '.join("curry" if i in sabji else i for i in j.split())
        if re.search('jamoon' , j):
            dish_liked[j] = ' '.join("jamun" if i in jamoon else i for i in j.split())
        if re.search('barfi' , j):
            dish_liked[j] = ' '.join("burfi" if i in barfi else i for i in j.split())
        if re.search('chawal' , j):
            dish_liked[j] = ' '.join("rice" if i in chawal else i for i in j.split())
    for j,z in zip(dish_liked,range(len(dish_liked))):
        if re.search('maggi' , j):
            dish_liked[z] = 'maggi'
        elif re.search('ice cream' , j):
            dish_liked[z] = 'icecream'
        elif re.search('ice tea' , j):
            dish_liked[z] = 'ice tea'
        elif re.search('icecream' , j):
            dish_liked[z] = 'icecream'
        elif re.search('noodle' , j):
            dish_liked[z] = 'noodles'
        elif re.search('pizza' , j):
            dish_liked[z] = 'pizza'
        elif re.search('burger' , j):
            dish_liked[z] = 'burger'
        elif re.search('pulav' , j ):
            dish_liked[z] = 'pulao'
        elif re.search('pulao' , j):
            dish_liked[z] = 'pulao'
        elif re.search('biryani' , j):
            dish_liked[z] = 'biryani'
        elif re.search('biriyani' , j):
            dish_liked[z] = 'biryani'
        elif re.search('garlic bread' , j):
            dish_liked[z] = 'garlic bread'
        elif re.search('cappuccino' , j):
            dish_liked[z] = 'cappuccino'
        elif re.search('frapp' , j):
            dish_liked[z] = 'frappuccino'
        elif re.search('tea' , j):
            dish_liked[z] = 'tea'
        elif re.search('cold coffee' , j):
            dish_liked[z] = 'cold coffee'
        elif re.search('coffee' , j):
            dish_liked[z] = 'coffee'
        elif re.search('sandwich' , j):
            dish_liked[z] = 'sandwich'
        elif re.search('dosa' ,j):
            dish_liked[z] = 'dosa'
        elif re.search('idli' , j):
            dish_liked[z] = 'idli'
        elif re.search('vada pav' , j):
            dish_liked[z] = 'vada pav'
        elif re.search('momos' , j):
            dish_liked[z] = 'momos'
        elif re.search('roti' , j):
            dish_liked[z] = 'roti'
        elif re.search('pani puri' , j):
            dish_liked[z] = 'panipuri'
        elif re.search('soup' , j):
            dish_liked[z] = 'soup'
        elif re.search('fudge' , j):
            dish_liked[z] = 'fudge'
        elif re.search('cheesecake' , j):
            dish_liked[z] = 'cheesecake'
        elif re.search('pancake' , j):
            dish_liked[z] = 'pancake'
        elif re.search('brownie' , j):
            dish_liked[z] = 'brownie'
        elif re.search('cake' , j):
            dish_liked[z] = 'cake'
        elif re.search('pasta' , j):
            dish_liked[z] = 'pasta'
        elif re.search(' papdi' , j):
            dish_liked[z] ='papdi'
        elif re.search('sushi', j):
            dish_liked[z] = 'sushi'
        elif re.search('roll' , j):
            dish_liked[z] = 'roll'
        elif re.search('fish fry' , j):
            dish_liked[z] = 'fish fry'
        elif re.search('fry' , j):
            dish_liked[z] = 'fry'
        elif re.search('fruit salad' , j):
            dish_liked[z] = 'fruit salad'
        elif re.search('salad' , j):
            dish_liked[z] = 'salad'
        elif re.search('mocktail' , j):
            dish_liked[z] = 'mocktail'
        elif re.search('cocktail' , j):
            dish_liked[z] = 'cocktail'
        elif re.search('chaat' , j):
            dish_liked[z] = 'chaat'
        elif re.search('donut' , j):
            dish_liked[z] = 'donut'
        elif re.search('parata' , j):
            dish_liked[z] = 'parata'
        elif re.search('beer' , j):
            dish_liked[z] = 'beer'
        elif re.search('shake' , j):
            dish_liked[z] = 'shake'
        elif re.search('juice' , j):
            dish_liked[z] = 'juice'
        elif re.search('beef' , j):
            dish_liked[z] = 'beef'
        elif re.search('burrito' , j):
            dish_liked[z] = 'burrito'
        elif re.search('taco' , j):
            dish_liked[z] ='taco'
        elif re.search('nachos' , j):
            dish_liked[z] = 'nachos'
        elif re.search('manchu' , j):
            dish_liked[z] = 'manchurian'
        elif re.search('kulch' , j):
            dish_liked[z] = 'kulcha'
        elif re.search('kulfi' , j):
            dish_liked[z] = 'kulfi'
        elif re.search('kofta' , j):
            dish_liked[z] = 'kofta'
        elif re.search('mojito' , j):
            dish_liked[z] = 'mojito'
        elif re.search('lassi' , j):
            dish_liked[z] = 'lassi'
        elif re.search('naan' , j):
            dish_liked[z] = 'naan'
        elif re.search('fries' , j):
            dish_liked[z] = 'fries'
        elif re.search('papad' , j):
            dish_liked[z] = 'papad'
        elif re.search('pastry' , j):
            dish_liked[z] = 'pastry'
        elif re.search('prawn' , j):
            dish_liked[z] = 'prawn'
        elif re.search('wine' , j):
            dish_liked[z] = 'wine'
        elif re.search('custard' , j):
            dish_liked[z] = 'custard'
        elif re.search('kebab' , j):
            dish_liked[z] = 'kebab'
        elif re.search('toast' , j):
            dish_liked[z] = 'toast'
        elif re.search('wrap' , j):
            dish_liked[z] = 'wrap'
        elif re.search('raita' , j):
            dish_liked[z] = 'raita'
        elif re.search('rabdi' , j):
            dish_liked[z] = 'rabdi'
        elif re.search('halwa' , j):
            dish_liked[z] = 'halwa'
        elif re.search('poha' , j):
            dish_liked[z] = 'poha'
        elif re.search('lemonade' , j):
            dish_liked[z] = 'lemonade'
        elif re.search('biscuit' ,j):
            dish_liked[z] = 'biscuit'
        elif re.search('waffle' , j):
            dish_liked[z] = 'waffle'
        elif re.search('omelette' , j):
            dish_liked[z] = 'omelette'
        elif re.search('pako' , j):
            dish_liked[z] = 'pakoda'
        elif re.search('pudding' , j):
            dish_liked[z] = 'pudding'
        elif re.search('dabeli' , j):
            dish_liked[z] = 'dabeli'
        elif re.search('sausage' , j):
            dish_liked[z] = 'sausages'
        elif re.search('lol' , j):
            dish_liked[z] = 'lollipop'
        elif re.search('shawa' , j):
            dish_liked[z] = 'shawarma'
        elif re.search('muffin' , j):
            dish_liked[z] = 'muffin'
        elif re.search('frit' , j):
            dish_liked[z] = 'fritters'
        elif re.search('falooda' , j):
            dish_liked[z] = 'falooda'
        elif re.search('soda' , j):
            dish_liked[z] = 'soda'
        elif re.search('rajma' , j):
            dish_liked[z] = 'rajma rice'
        elif re.search('nuggets' , j):
            dish_liked[z] = 'nuggets'
        elif re.search('smoo' , j):
            dish_liked[z] = 'smoothies'
        elif re.search('chai' , j):
            dish_liked[z] = 'tea'
        elif re.search('cooki' , j):
            dish_liked[z] = 'cookies'
        elif re.search('jamun' , j):
            dish_liked[z] = 'jamun'
        elif re.search('chips' , j):
            dish_liked[z] = 'chips'
        elif re.search('puff' , j):
            dish_liked[z] = 'puff'
        elif re.search('pop' , j):
            dish_liked[z] = 'popcorn'
        elif re.search('maca' , j):
            dish_liked[z] = 'macarons'
        elif re.search('walnut' , j):
            dish_liked[z] = 'walnut'
        elif re.search('burfi' , j):
            dish_liked[z] = 'burfi'
        elif re.search('peda' , j):
            dish_liked[z] = 'peda'
        elif re.search('bread' , j):
            dish_liked[z] = 'bread'
        elif re.search('scoop' , j):
            dish_liked[z] = 'icecream'
        elif re.search('rasg' , j):
            dish_liked[z] = 'rasgulla'
        elif re.search('ghee rice' , j):
            dish_liked[z] = 'ghee rice'
        elif re.search('ladd' , j):
            dish_liked[z] = 'laddo'
        elif re.search('tiff' , j):
            dish_liked[z] = 'south tiffin'
        elif re.search('sharb' , j):
            dish_liked[z] = 'sharbat'
        elif re.search('khich' , j):
            dish_liked[z] = 'khichadi'
        elif re.search('kich' , j):
            dish_liked[z] = 'khichadi'
        elif re.search('rice bowl' , j):
            dish_liked[z] = 'rice bowl'
        elif re.search('butter milk' , j):
            dish_liked[z] = 'buttermilk'
        elif re.search('buttermilk' , j):
            dish_liked[z] = 'buttermilk'
        elif re.search('smile' , j):
            dish_liked[z] = 'smiley'
        elif re.search('break' , j):
            dish_liked[z] = 'breakfast'
        elif re.search('lunch' , j):
            dish_liked[z] = 'lunch'
        elif re.search('morn' , j):
            dish_liked[z] = 'breakfast'
        elif re.search('nutella' , j):
            dish_liked[z] = 'nutella'
        elif re.search('wedge' , j):
            dish_liked[z] = 'wedges'
        elif re.search('crep' , j):
            dish_liked[z] = 'crepe'
        elif re.search('lime' , j):
            dish_liked[z] = 'lime'
        elif re.search('spag' , j):
            dish_liked[z] = 'spaghetti'
        elif re.search('samosa' , j):
            dish_liked[z] = 'samosa'
        elif re.search('hummus' , j):
            dish_liked[z] = 'hummus'
        elif re.search('fried rice' , j):
            dish_liked[j] = 'fried rice'
        elif re.search('oatmeal' , j):
            dish_liked[z] = 'oatmeal'
        elif re.search('truffle' , j):
            dish_liked[z] ='truffle'
    return dish_liked

# %%
def clean_cui_p1(user):
    user_cuisine = []
    for i in timing.Cuisines:
            res =eval(i)
            for j in res:
                user_cuisine.append(j)
    user_cui1 = []
    for i in user_cuisine:
        w = i.lower()
        user_cui1.append(w)
    return user_cui1

# %%
def clean_cui_p2(cuisines):
    for j in range(len(cuisines)):
        if re.search('kebab' , cuisines[j]):
            cuisines[j] = 'middle eastern'
        elif re.search('pizza' , cuisines[j]):
            cuisines[j] = 'italian'
        elif re.search('biryani' , cuisines[j]):
            cuisines[j] = 'mughlai'
        elif re.search('modern indian',cuisines[j]):
            cuisines[j] = 'indian'
        elif re.search('sandwich' , cuisines[j]):
            cuisines[j] = 'fast food'
        elif re.search('burger' , cuisines[j]):
            cuisines[j] = 'american'
        elif re.search('south american' , cuisines[j]):
            cuisines[j] = 'american'
        elif re.search('hot dogs' , cuisines[j]):
            cuisines[j] = 'german'
        elif re.search('rolls' , cuisines[j]):
            cuisines[j] = 'fast food'
        elif re.search('tea' , cuisines[j]):
            cuisines[j] = 'beverages'
        elif re.search('grill' , cuisines[j]):
            cuisines[j] = 'indian'
        elif re.search('cafe' , cuisines[j]):
            cuisines[j] = 'fast food'
        elif re.search('drinks only' , cuisines[j]):
            cuisines[j] = 'beverages'
        elif re.search('juices' , cuisines[j]):
            cuisines[j] = 'beverages'
        elif re.search('bar food' , cuisines[j]):
            cuisines[j]= 'continental'
        elif re.search('coffee' , cuisines[j]):
            cuisines[j] = 'beverages'
        elif re.search('bakery' , cuisines[j]):
            cuisines[j] = 'desserts'
        elif re.search('healthy food' , cuisines[j]):
            cuisines[j] = 'indian'
        elif re.search('salad' , cuisines[j]):
            cuisines[j] = 'indian'
        elif re.search('charcoal chicken' , cuisines[j]):
            cuisines[j] = 'bbq'
        elif re.search('mithai' , cuisines[j]):
            cuisines[j] = 'dessert'
        elif re.search('wraps' , cuisines[j]):
            cuisines[j] = 'fast food'
        elif re.search('finger food' , cuisines[j]):
            cuisines[j] = 'fast food'
        elif re.search('street food' , cuisines[j]):
            cuisines[j] = 'fast food'
        elif re.search('steak' , cuisines[j]):
            cuisines[j] = 'bbq'
        elif re.search('roast chicken' , cuisines[j]):
            cuisines[j] = 'bbq'
        return cuisines

# %% [markdown]
# ### Function to get the recommendations based on location and cost factors from user's past history

# %%
def chooseloc(df,la,lo,cost):
    df['man_dist']=0
    df['loc_dist_km']=0
    lm=[]
    lk=[]
    for i,j in (zip(df.iloc[:,16],df.iloc[:,17])):
        p = pi/180
        a = 0.5 - cos((la-float(i))*p)/2 + cos(la*p) * cos(float(i)*p) * (1-cos((lo-float(j))*p))/2
        d=12742 * asin(sqrt(a))
        m=abs(float(i)-la)+abs(float(j)-lo)
        lm.append(m)
        lk.append(d)
    df["man_dist"]=lm
    df["loc_dist_km"]=lk
    df=df[(df['approx_cost(for two people)']<cost)]
    df=df[df['loc_dist_km']<5]
    df=df[df['final_rate']>3]
    df=df.sort_values(by=["final_rate","loc_dist_km"],ascending=(False,True))
    return df

# %% [markdown]
# ### Recommending top 100 restaurants based on cosine similarity

# %%
def recommend(cosine_similarities,df):
    # Create a list to put top restaurants
    count=0
    restaurant_recom = []

        # Find the restaurants with a similar cosine-sim value and order them from bigges number
    score_series = pd.Series(cosine_similarities[0]).sort_values(ascending=False)
        # Extract top 30 restaurant indexes with a similar cosine-sim value
    top_indexes = list(score_series.iloc[0:100].index)
        # Names of the top 30 restaurants
    for each in top_indexes:
        restaurant_recom.append(list(df.index)[each])

    df_new = pd.DataFrame(columns=df.columns)

    for item in  restaurant_recom:
        df_new = df_new.append(pd.DataFrame(df[df.columns][df.index == item].sample()))
    return df_new

# %% [markdown]
# ### Function to find the Cosine similarities between the users data and restaurant data based on dish_liked and cuisines.

# %%
def count_cosine(df_dish,df_cui,user_dish3,user_cui2):
    
    vect_dish= CountVectorizer(analyzer = lambda x:x)
    vect_cui = CountVectorizer(analyzer = lambda x:x)
    df_dish_mat=vect_dish.fit_transform(df_dish).toarray()
    df_cuisine_mat=vect_cui.fit_transform(df_cui).toarray()
    user_dish_mat=vect_dish.transform([user_dish3]).toarray()
    user_cuisine_mat=vect_cui.transform([user_cui2]).toarray()
    cosine_similarities_dishes = cosine_similarity(user_dish_mat,df_dish_mat)
    cosine_similarities_cuisines = cosine_similarity(user_cuisine_mat,df_cuisine_mat)
    return cosine_similarities_dishes,cosine_similarities_cuisines

# %%
df=pd.read_pickle("final_final.pkl")

# %%
df_cui,df_dish = df_dish_cui(df)

# %% [markdown]
# ### Finding the recommendations for the user data based on his past history.

# %%
user=pd.read_csv("user1_final.csv")
user["Time"]=pd.to_datetime((user['Time']))
t=dt.time(14,30)
timing = timing_user(user,t)
rest_id = list(user.Restaurant_Id)
if(len(timing)==0):
    print("recommendation based on features location and cost")
    final_rec_llc=chooseloc(df,lat,long,costt)
else:
    dish_clean_1=clean_user_p1(timing)
    final_dish=clean_user_p2(dish_clean_1)
    cui_clean_1 = clean_cui_p1(timing)
    final_cuisines = clean_cui_p2(cui_clean_1)
    cosine_simi_dish,cosine_simi_cui = count_cosine(df_dish,df_cui,(final_dish),list(set(final_cuisines)))
    lat=12.9292731
    long=77.5824229
    #cosine_similarity based on dishes
    temp_rec_dish=recommend(cosine_simi_dish,df)
    costt=max(user['Price'])+100
    final_rec_dish=chooseloc(temp_rec_dish,lat,long,costt)
    for i in final_rec_dish.index:
        if i in rest_id:
            final_rec_dish = final_rec_dish.drop(i)
    final_rec_dish
# Out:
# (26, 20)
# (23, 20)

# %%
temp_rec_cui=recommend(cosine_simi_cui,df)
rest_id = list(user.Restaurant_Id)
costt=max(user['Price'])+100
final_rec_cui=chooseloc(temp_rec_cui,lat,long,costt)
print("recommendation based on features location, cost and cuisines")
for i in final_rec_cui.index:
    if i in rest_id:
        final_rec_cui = final_rec_cui.drop(i)
final_rec_cui

# %% [markdown]
# ### Evaluation Metrics

# %%
l=[]
for i in final_dish:
    c=0
    for j in final_rec_dish['dish_liked']:
        if i in j:
            c+=1
    l.append((i,c))
print(set(l))
# Out:
# {('ghee rice', 3), ('momos', 1), ('noodles', 3), ('butter chicken', 7), ('paneer tikka', 1), ('rajma rice', 0), ('fudge', 0), ('veg kadhai', 0), ('omelette', 0), ('burger', 5), ('chicken guntur', 0), ('manchurian', 2), ('chicken grill', 5), ('biryani', 13), ('parata', 8), ('toori chicken', 4), ('butter chicken masala', 0), ('fries', 12), ('raita', 0), ('roll', 7), ('mughlai chicken', 0), ('khichadi', 1)}
